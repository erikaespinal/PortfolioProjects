# %%
#Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib 
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configuration of the plots we will create

# %%
#REad in the data
df = pd.read_csv('movies.csv')

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_rows', 60)

# %%
#Look at the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#Check for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df.shape
# Out:
# (7668, 15)

# %%
# create a Boolean mask of null values in rating column
null_mask = df['budget'].isnull()

# select the rows with null values in rating column
null_rows = df[null_mask]

# display the null rows
null_rows
# Out:
#                   name     rating   genre  year  \
# 16                Fame          R   Drama  1980
# 19          Stir Crazy          R  Comedy  1980
# 24        Urban Cowboy         PG   Drama  1980
# 25      Altered States          R  Horror  1980
# 26     Little Darlings          R  Comedy  1980
# ...                ...        ...     ...   ...
# 7657              Leap        NaN   Drama  2020
# 7659         I Am Fear  Not Rated  Horror  2020
# 7660  Aloha Surf Hotel        NaN  Comedy  2020
# 7664       Dream Round        NaN  Comedy  2020
# 7667         Tee em el        NaN  Horror  2020
#
#                                 released  score    votes            director  \
# 16          May 16, 1980 (United States)    6.6  21000.0         Alan Parker
# 19     December 12, 1980 (United States)    6.8  26000.0      Sidney Poitier
# 24          June 6, 1980 (United States)    6.4  14000.0       James Bridges
# ...

# %%
#Check for nulls in new df
# create a Boolean mask of null values in rating col
null_mask2 = df_fix_rating_nulls['rating'].isnull()

# select the rows with null values in rating col
null_rows2 = df_fix_rating_nulls[null_mask2]

# display the null rows
null_rows2
# Out:
# Empty DataFrame
# Columns: [name, rating, genre, year, released, score, votes, director, writer, star, country, budget, gross, company, runtime]
# Index: []

# %%
df_fix_rating_nulls.isnull().sum()
# Out:
# name           0
# rating         0
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
#Finding nulls in budget grouping by budget and year 

null_budget_count = df[df['budget'].isnull()].groupby(['year']).size()

# %%
null_budget_count
# Out:
# year
# 1980     45
# 1981     45
# 1982     52
# 1983     55
# 1984     77
# 1985    102
# 1986     99
# 1987     92
# 1988     67
# 1989     81
# 1990     87
# 1991     84
# 1992     66
# 1993     56
# 1994     71
# 1995     61
# 1996     56
# 1997     50
# 1998     51
# 1999     36
# 2000     37
# 2001     34
# 2002     27
# 2003     41
# 2004     42
# 2005     30
# 2006     36
# 2007     43
# 2008     28
# 2009     29
# 2010     36
# 2011     40
# 2012     37
# 2013     39
# 2014     37
# 2015     43
# 2016     41
# 2017     67
# 2018     57
# 2019     84
# 2020     10
# dtype: int64

# %%
# Creating another dataframe to drop all rows with null values
df3 = df.copy()

# %%
df3.dropna(inplace=True)

# %%
df3.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df3.shape
# Out:
# (5421, 15)

# %%
#Change the data type to remove decimal and zero after dollar amounts

df3['budget']= df3['budget'].astype('int64')

df3['gross'] = df3['gross'].astype('int64')

# %%
df3
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
#Fix year release date column to only show the year
df3['yearcorrect'] = pd.to_datetime(df3['released'], format= '%B %d %Y (%A)').dt.year

# %%
# Define a regular expression pattern to extract the year from the 'released' column
pattern = r'\((\d{4})\)'

# Extract the year using the pattern and assign to a new 'year' column
df3['yearcorrect'] = df3['released'].str.extract(pattern, expand=False)

# Convert the 'year' column to numeric type
df3['yearcorrect'] = pd.to_numeric(df3['year'])

# %%
df3
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
#Order by gross revenue

df3 = df3.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
#Check for duplicates and drop

df3['company'].sort_values(ascending=False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
#                        ...
# 2929                          1492 Pictures
# 3525                          1492 Pictures
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 5421, dtype: object

# %% [markdown]
# ### Correlation

# %%
#Scatterplot with budget vs gross

plt.scatter(x=df3['budget'], y=df3['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget') 
plt.show()

# %%
pd.set_option('display.max_rows',60)

# %%
df3
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
#Regression plot with seaborn
#plotting budget vs gross
import scipy.stats as stats

# Create scatter plot with regression line
ax = sns.regplot(x ='budget', y='gross',  data =df3, scatter_kws = {"color":"red"}, line_kws={"color":"blue"})


# Calculate Pearson correlation coefficient and p-value
corr_coef, p_value = stats.pearsonr(df3["budget"], df3["gross"])

# Add correlation coefficient to plot
ax.text(x=0.95, y=0.95, s=f"r = {corr_coef:.2f}, p = {p_value:.2e}", ha="right", va="top", transform=ax.transAxes)
# Out:
# Text(0.95, 0.95, 'r = 0.74, p = 0.00e+00')

# %% [markdown]
# #### The above graph shows a coefficient of 0.74 which suggests a strong positive linear relationship between the investment in the film budget and the resulting gross sales. The p-value indicates the probability of observing a correlation coefficient as extreme as the one calculated, assuming there is no correlation between the variables in the population. A p-value of 0.00e+00 that is displayed means that the probability of observing such a strong correlation coefficient by chance is essentially zero, this suggests that there is a significant correlation between the budget of a film and its gross earnings.

# %%
df3.corr()
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score        0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes        0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget       0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross        0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime      0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# yearcorrect  1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
#
#              yearcorrect
# year            1.000000
# score           0.056386
# votes           0.206021
# budget          0.327722
# gross           0.274321
# runtime         0.075077
# yearcorrect     1.000000

# %%
df3.corr(method='pearson')
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score        0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes        0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget       0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross        0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime      0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# yearcorrect  1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
#
#              yearcorrect
# year            1.000000
# score           0.056386
# votes           0.206021
# budget          0.327722
# gross           0.274321
# runtime         0.075077
# yearcorrect     1.000000

# %%
df3.corr(method='kendall')
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
# score        0.039389  1.000000  0.350185 -0.006406  0.124943  0.292254
# votes        0.296512  0.350185  1.000000  0.346274  0.553625  0.205344
# budget       0.220833 -0.006406  0.346274  1.000000  0.512057  0.231278
# gross        0.239539  0.124943  0.553625  0.512057  1.000000  0.176979
# runtime      0.064824  0.292254  0.205344  0.231278  0.176979  1.000000
# yearcorrect  1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
#
#              yearcorrect
# year            1.000000
# score           0.039389
# votes           0.296512
# budget          0.220833
# gross           0.239539
# runtime         0.064824
# yearcorrect     1.000000

# %%
df3.corr(method='spearman')
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.057741  0.427623  0.312886  0.351045  0.095444
# score        0.057741  1.000000  0.495409 -0.009971  0.183192  0.412155
# votes        0.427623  0.495409  1.000000  0.493461  0.745793  0.300621
# budget       0.312886 -0.009971  0.493461  1.000000  0.692958  0.330794
# gross        0.351045  0.183192  0.745793  0.692958  1.000000  0.257400
# runtime      0.095444  0.412155  0.300621  0.330794  0.257400  1.000000
# yearcorrect  1.000000  0.057741  0.427623  0.312886  0.351045  0.095444
#
#              yearcorrect
# year            1.000000
# score           0.057741
# votes           0.427623
# budget          0.312886
# gross           0.351045
# runtime         0.095444
# yearcorrect     1.000000

# %%
correlation_matrix = df3.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True) 
plt.title('Correlation Matrix for Numeric Values')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features') 


plt.show()

# %%
#Look at company (not numeric but we can create a numeric representation instead of a string) 
df3.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
df3_numerical = df3

for col_name in df3_numerical.columns:
    if(df3_numerical[col_name].dtype == 'object'):
        df3_numerical[col_name] = df3_numerical[col_name].astype('category')
        df3_numerical[col_name] = df3_numerical[col_name].cat.codes
df3_numerical
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5640  3794       6      6  2009       890    5.8     3500.0       585    2924
# 2434  2969       5      0  1993      1467    4.5     1900.0      1805    3102
# 3681  1595       3      6  2000      1721    6.8    43000.0       952    1683
# 272   2909       6      9  1982      1525    3.9     2300.0       261      55
# 3203  4966       5      4  1997      2152    5.7     5800.0       651     161
#
# ...

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
correlation_matrix = df3_numerical.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True) 
plt.title('Correlation Matrix for Numeric Values')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features') 


plt.show()

# %%
df3_numerical.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year         0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released    -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score        0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
correlation_matrix = df3_numerical.corr()

corr_pairs = correlation_matrix.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#              score          0.014450
#              votes          0.012615
#              director       0.015246
#              writer         0.012880
#              star          -0.006882
#              country       -0.025490
#              budget         0.023392
#              gross          0.005639
#              company        0.021697
#              runtime        0.010850
#              yearcorrect    0.025542
# rating       name          -0.029234
#              rating         1.000000
#              genre          0.147796
#              year           0.019499
#              released       0.018083
#              score          0.065983
#              votes          0.006031
#              director       0.014656
#              writer        -0.003149
# ...

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.368523
# budget       genre         -0.368523
# gross        genre         -0.244101
# genre        gross         -0.244101
# budget       rating        -0.203946
# rating       budget        -0.203946
# gross        rating        -0.181906
# rating       gross         -0.181906
# votes        genre         -0.135990
# genre        votes         -0.135990
# rating       company       -0.092357
# company      rating        -0.092357
# year         genre         -0.073167
# genre        year          -0.073167
# yearcorrect  genre         -0.073167
# genre        yearcorrect   -0.073167
# company      genre         -0.071334
# genre        company       -0.071334
# country      yearcorrect   -0.066748
# yearcorrect  country       -0.066748
# country      year          -0.066748
# year         country       -0.066748
# runtime      genre         -0.059237
# genre        runtime       -0.059237
# country      score         -0.043051
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# gross        votes          0.614751
# votes        gross          0.614751
# budget       gross          0.740247
# gross        budget         0.740247
# yearcorrect  year           1.000000
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         yearcorrect    1.000000
#              year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64
